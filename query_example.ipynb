# %%
# %load_ext autoreload
# %autoreload 2
import spike_queries
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
query = "<>subj:[w]Obama $was $born $in obj:Hawaii"
dataset_name = "wiki"
num_results = 10
query_type = "syntactic"

df = spike_queries.perform_query(query, dataset_name, num_results, query_type)
# Out:
# {
#   "queries": {"syntactic": "<>subj:[w]Obama $was $born $in obj:Hawaii"},
#   "data_set_name": "wiki"
# }

# %%
df.head()
# Out:
#                                          sentence_id                    subj  \
# 0                                             553233                   Obama
# 1                                            2041034         President Obama
# 2                                            2053476  President Barack Obama
# 3                                            3859509            Barack Obama
# 4  There is something there that the president do...                     NaN
#
#       obj                               title  article_link  pmc_id  doi  \
# 0  States                          Carol Vita           NaN     NaN  NaN
# 1  States     Political positions of Jeb Bush           NaN     NaN  NaN
# 2  States                    Wayne Allyn Root           NaN     NaN  NaN
# 3  Hawaii  Political positions of Sarah Palin           NaN     NaN  NaN
# 4     NaN                                 NaN           NaN     NaN  NaN
#
#    pdf_sha  pubmed_id  msft_id  subj_first_index  subj_last_index  \
# 0      NaN        NaN      NaN              23.0             23.0
# 1      NaN        NaN      NaN              15.0             16.0
# 2      NaN        NaN      NaN              10.0             12.0
# 3      NaN        NaN      NaN               3.0              4.0
# 4      NaN        NaN      NaN               NaN              NaN
#
#    obj_first_index  obj_last_index  \
# 0             30.0            30.0
# 1             23.0            23.0
# 2             19.0            19.0
# 3              8.0             8.0
# 4              NaN             NaN
#
#                                        sentence_text  \
# 0  Vita was a sponsor for a lawsuit to have Barac...
# 1  In 2011 , Bush wrote : " Republican candidates...
# 2  Root was a leading proponent of the conspiracy...
# 3  Although she believes Barack Obama was born in...
# 4                                                NaN
#
#                                       paragraph_text
# 0  Vita was a sponsor for a lawsuit to have Barac...
# 1  Bush has repudiated the Barack Obama citizensh...
# 2  Root was a leading proponent of the conspiracy...
# 3  In February 2011, Palin dismissed discussion o...
# 4                                                NaN
